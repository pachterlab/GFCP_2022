# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/GFCP_2021/blob/main/notebooks/phaseplots_lme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Figure 5: Imputation introduces distortions in phase plots computed from real data.

# %% [markdown]
# In this notebook, we examine the La Manno et al. human forebrain dataset, analyze it using the standard `velocyto` workflow, and investigate the effect of imputation neighborhoods on the appearance of phase plots and inferred parameters.

# %% [markdown]
# #Dependencies

# %%
import time
t1 = time.time()

# %%
## uncomment this cell if run in colab ##

# %%capture
# !pip install --upgrade git+https://github.com/meichenfang/velocyto.py.git
# !pip install scanpy umap-learn

# %%
# !mkdir -p figure
# !mkdir -p data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/rnavelocity/hgForebrainGlut.loom /content/data

# %% [markdown]
# Here, the `hgForebrainGlut.loom` and `vis.py` files need to be uploaded.

# %%
from vis import *
# Out:
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
## run locally ##
# %cd ../../GFCP_2021
# from vis import * 
# %cd notebooks

# %% [markdown]
# #Load data and preprocess

# %%
vlm = vcy.VelocytoLoom(loom_filepath="data/hgForebrainGlut.loom")
preprocess(vlm)

# %% [markdown]
# #Generate Figure 5

# %%
plt.rcParams.update({'font.size': 16})

fig=phasePlots(vlm,genes=["STMN2","ELAVL4","DCX","GRIA3"],n_neighs=[0,50,100,200],n_neighs_list=np.arange(0,550,50),sim=False,zero_is_special=True)

fig.savefig('figure/phaseplots_lme_raw.png',dpi=600)

# %%
t2 = time.time()
print('Runtime: {:.2f} seconds.'.format(t2-t1))
# Out:
# Runtime: 298.02 seconds.
