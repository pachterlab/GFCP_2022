# %% [markdown]
# # Dependencies

# %%
## uncomment this cell if run in colab ##

#%%capture
#pip install --upgrade git+https://github.com/meichenfang/velocyto.py.git
#pip install scanpy umap-learn

#!git clone https://github.com/pachterlab/GFCP_2021.git
#!cd GFCP_2021
#from vis import *

# %%
## run locally ##
# %cd ../../GFCP_2021
from vis import * 
# %cd notebooks
# Out:
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/notebooks

# %% [markdown]
# # Load data and preprocess

# %%
vlm = vcy.VelocytoLoom(loom_filepath="data/hgForebrainGlut.loom")
preprocess(vlm)

# %% [markdown]
# # Generate figure 8

# %%
plt.rcParams.update({'font.size': 22})
#fig, frac=angleDevPlots(vlm,Trans=["sqrt","log"],n_neighs=[50])
fig, frac=angleDevPlots(vlm,Trans=["sqrt","log","linear"],n_neighs=[50,100,200])
plt.legend(loc=1 ,prop={'size': 12})
plt.show()
fig.savefig('../figure/figure_8.png',dpi=600)
# Out:
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=log
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=linear
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=log
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=linear
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=log
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
# /Users/fang/OneDrive - California Institute of Technology/Caltech/Research/Pachter/RNA velocity/What_is_RNA_velocity/GFCP_2021/vis.py:1167: UserWarning: Nan values in corrcoef, setting them to 0. Tansformation=linear
#   warnings.warn("Nan values in corrcoef, setting them to 0. Tansformation=" + str(trans))
